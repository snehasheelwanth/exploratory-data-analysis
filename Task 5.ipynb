# %% [markdown]
# # 1. Import Libraries & Load Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"C:\Users\SNEHA SHEELWANTH\Downloads\titanic_sample.csv")

# %%
df
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 1            2         1       1      Cumings, Mrs. John Bradley  female
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 3            4         1       1    Futrelle, Mrs. Jacques Heath  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 6            7         1       1         McCarthy, Mr. Timothy J    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
# 8            9         1       2           Johnson, Mrs. Oscar W  female
# 9           10         0       3           Nasser, Mrs. Nicholas  female
#
#     Age  SibSp  Parch            Ticket     Fare Embarked
# 0  22.0      1      0         A/5 21171   7.2500        S
# ...

# %% [markdown]
# # 2. Basic Data Info

# %%
print(df.shape)        # Rows & Columns
print(df.info())       # Data types & nulls
print(df.describe())   # Stats summary
print(df['Survived'].value_counts())  # Class balance
# Out:
# (10, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  10 non-null     int64
#  1   Survived     10 non-null     int64
#  2   Pclass       10 non-null     int64
#  3   Name         10 non-null     object
#  4   Sex          10 non-null     object
#  5   Age          9 non-null      float64
#  6   SibSp        10 non-null     int64
#  7   Parch        10 non-null     int64
#  8   Ticket       10 non-null     object
#  9   Fare         10 non-null     float64
#  10  Embarked     10 non-null     object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 1012.0+ bytes
# None
#        PassengerId   Survived     Pclass        Age      SibSp      Parch  \
# count     10.00000  10.000000  10.000000   9.000000  10.000000  10.000000
# mean       5.50000   0.500000   2.300000  28.111111   0.700000   0.300000
# ...

# %% [markdown]
# # 3. Handle Missing Values

# %%
df.isnull().sum()
df['Age'] = df['Age'].fillna(df['Age'].median())
df
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 1            2         1       1      Cumings, Mrs. John Bradley  female
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 3            4         1       1    Futrelle, Mrs. Jacques Heath  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 6            7         1       1         McCarthy, Mr. Timothy J    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
# 8            9         1       2           Johnson, Mrs. Oscar W  female
# 9           10         0       3           Nasser, Mrs. Nicholas  female
#
#     Age  SibSp  Parch            Ticket     Fare Embarked
# 0  22.0      1      0         A/5 21171   7.2500        S
# ...

# %% [markdown]
# # 4. Univariate Analysis

# %%
sns.countplot(x='Survived', data=df)
plt.show()

sns.histplot(df['Age'], bins=10, kde=True)
plt.show()

# %% [markdown]
# # 5. Bivariate Analysis

# %%
sns.barplot(x='Pclass', y='Survived', data=df)
sns.boxplot(x='Survived', y='Age', data=df)
plt.show()

# %% [markdown]
# # 6. Correlation

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # 7. Pairplot for Relationships

# %%
sns.pairplot(df[['Survived', 'Pclass', 'Age', 'Fare']], hue='Survived')
plt.show()

# %% [markdown]
# 8. Observations & Summary
#
# Observation example: Survival rate was higher for 1st class passengers.
#
# Observation example: Younger passengers had slightly better survival chances.
#
# Observation example: Fare is positively correlated with survival.
